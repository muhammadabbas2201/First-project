# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadabbas2201/First-project/blob/main/Lecture_3_and_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/single linear regression data.csv')
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.12/dist-packages/pandas/__init__.py'>

# %%
df
# Out:
#    ID  Milage  Price
# 0   1  156005  14328
# 1   2  192045  11621
# 2   3  230000   8800
# 3   4   45901  19900
# 4   5  108966  16467

# %%
plt.xlabel('Milage')
plt.ylabel('Price')
plt.scatter(df.Milage,df.Price)

# %%
lr =linear_model.LinearRegression()
lr.fit(df[['Milage']],df.Price)
# Out:
# LinearRegression()

# %%
lr.predict([[50000]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([19951.3973277])

# %%
lr.coef_
# Out:
# array([-0.0593083])

# %%
lr.intercept_
# Out:
# np.float64(22916.81236159631)

# %%
Predicted = -0.0593083 * 50000 + 22916.81236159631
print(Predicted)
# Out:
# 19951.397361596308

# %%
lr.predict([[75000]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([18468.68981075])

# %%
lr.coef_
# Out:
# array([-0.0593083])

# %%
lr.intercept_
# Out:
# np.float64(22916.81236159631)

# %%
predicted = -0.0593083 * 75000 + 22916.81236159631
predicted
# Out:
# 18468.689861596307

# %%
plt.xlabel('Milage',color ='Red')
plt.ylabel('Price', color = 'Red')
plt.scatter(df.Milage,df.Price)
plt.plot(df.Milage, lr.predict(df[["Milage"]]),color = 'Red')

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model

# %%
df=pd.read_excel('/content/car_sale_data.xlsx')
df.head()
# Out:
#     ID  Year  Cylinder  Milage  Price
# 0    0  2021       6.4  156005  14328
# 1    1  2016       4.0  192045  11521
# 2    2  2014       4.0  230000   8800
# 3    3  2023       NaN   45001  19900
# 4    4  2021       6.0  108566  16467

# %%
df.Cylinder.median()
# Out:
# 5.0

# %%
df.Cylinder.fillna(4 , inplace = True)
df.head()
# Out:
# /tmp/ipykernel_4921/3369990187.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Cylinder.fillna(4 , inplace = True)
#     ID  Year  Cylinder  Milage  Price
# 0    0  2021       6.4  156005  14328
# 1    1  2016       4.0  192045  11521
# 2    2  2014       4.0  230000   8800
# 3    3  2023       4.0   45001  19900
# 4    4  2021       6.0  108566  16467

# %%
lr = linear_model.LinearRegression()

# %%
lr.fit(df[['Year','Cylinder','Milage']],df.Price)
# Out:
# LinearRegression()

# %%
lr.predict([[2021,6.0,170000]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13747.70224665])

# %%
lr.score(df[['Year','Cylinder','Milage']],df.Price)
# Out:
# 0.9987282961707117

# %%
lr.coef_
# Out:
# array([ 3.16056667e+02, -4.25392616e+01, -4.39238368e-02])

# %%
lr.intercept_
# Out:
# np.float64(-617280.5332802793)

# %%
predicted = 3.16056667e+02 *2021+ -4.25392616e+01*6.0+ -4.39238368e-02*170000 -617280.5332802793
predicted
# Out:
# 13747.702901120763

# %%
lr.predict([[2022,4.0,12000]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([21088.80364633])

# %%
lr.score(df[['Year','Cylinder','Milage']],df.Price)
# Out:
# 0.9987282961707117

# %%
lr.coef_
# Out:
# array([ 3.16056667e+02, -4.25392616e+01, -4.39238368e-02])

# %%
lr.intercept_
# Out:
# np.float64(-617280.5332802793)

# %%
predicted  =3.16056667e+02*2022 -4.25392616e+01*4.0 -4.39238368e-02*12000 -617280.5232802793
predicted
# Out:
# 21088.814305720734

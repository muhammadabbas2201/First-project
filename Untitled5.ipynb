# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadabbas2201/First-project/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/Titanic-Dataset.csv')

# %%
current_palette1 = sns.color_palette()
sns.palplot(current_palette1)
plt.show()

# %%
current_palette = sns.color_palette()
sns.palplot(sns.color_palette("Reds"))
plt.show()

# %%
current_palette = sns.color_palette()
sns.palplot(sns.color_palette("BrBG",20))
plt.show()

# %%
current_palette = sns.color_palette()
sns.palplot(sns.color_palette("colorblind"))
plt.show()

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.histplot(df['Parch'],kde = False)
plt.show()

# %%
sns.distplot(df['Age'],hist = False)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.distplot(df['Age'])
plt.show()

# %%
sns.relplot(x='Age',y='Fare',col='Pclass',hue='Sex',style='Sex',kind='line', data=df)

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x='Age',y='Fare',hue = 'Sex', data=df)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Sex',y='Survived',hue='Pclass',data=df)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.stripplot(x='Sex',y='Age',hue='Pclass',data=df)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.swarmplot(x='Sex',y='Age',hue='Pclass',data=df)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(x='Sex',y='Age', data=df)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x='Survived',y='Age',hue = 'Sex', data=df)
plt.show()

# %%
sns.countplot(x='Survived',data = df,palette = 'Blues')
plt.shoe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3453/1834096211.py in <cell line: 0>()
#       1 sns.countplot(x='Survived',data = df,palette = 'Blues')
# ----> 2 plt.shoe()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'shoe'

# %%
plt.figure(figsize=(8,8))
sns.pointplot(x='Sex',y='Survived',hue = 'Pclass', data = df)
plt.show()

# %%
sns.lmplot(x='Age',y='Fare',data=df)
plt.show()

# %%
sns.regplot(x='Fare',y='Fare',data=df)
plt.show()

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(numeric_only=True),cmap = 'YlGnBu', annot=True,fmt='.2f')
plt.show()

# %%
g = sns.FacetGrid(df,col='Survived',row='Pclass')
g.map(plt.hist,'Age')
g.add_legend()
plt.show()
